# %%
from torchmetrics.text import WordErrorRate, CharErrorRate

# Load OCR output (predictions)
with open("../data/output_text__Cr.No.01-2017.txt", "r", encoding="utf-8") as f:
     ocr_output = f.read().strip()

# Load Truth data (ground truth)
with open("../data/truth_data_Cr.No.01-2017.txt", "r", encoding="utf-8") as f:
    truth_data = f.read().strip()

wer_metric = WordErrorRate()
cer_metric = CharErrorRate()

wer_score = wer_metric(ocr_output, truth_data)
cer_score = cer_metric(ocr_output, truth_data)

word_accuracy = 1 - wer_score
char_accuracy = 1 - cer_score

print(f"WER: {wer_score:.4f}")
print(f"CER: {cer_score:.4f}")
print(f"Word Accuracy: {word_accuracy:.4f}")
print(f"Character Accuracy: {char_accuracy:.4f}")
# Out:
# /home/arunachalam/Projects/cbcid/.venv/lib/python3.10/site-packages/torchmetrics/utilities/imports.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# WER: 0.3100
# CER: 0.1530
# Word Accuracy: 0.6900
# Character Accuracy: 0.8470

# %%
with open("../data/output_text__Cr.No.01-2017.txt", "r", encoding="utf-8") as f:
    text = f.read()
word_count = len(text.split())
char_count = len(text)
print("Total characters:", char_count)
print("Total words:", word_count)
# Out:
# Total characters: 9509
# Total words: 1088

# %%
with open("../data/truth_data_Cr.No.01-2017.txt", "r", encoding="utf-8") as f:
    text = f.read()
word_count = len(text.split())
char_count = len(text)
print("Total characters:", char_count)
print("Total words:", word_count)
# Out:
# Total characters: 9826
# Total words: 1171
